# %% [markdown]
# # 0 - Gather the Data

# %%
# %ls data
# Out:
#  O volume na unidade C não tem nome.
#  O Número de Série do Volume é 3C82-1FC7
#
#  Pasta de C:\Users\vitor\_Projetos_\LLM_Studies\data
#
# 09/12/2024  21:48    <DIR>          .
# 09/12/2024  22:02    <DIR>          ..
# 09/12/2024  21:48         8.773.018 visgatorag.pdf
#                1 arquivo(s)      8.773.018 bytes
#                2 pasta(s)   633.109.258.240 bytes disponíveis

# %% [markdown]
# # 1 - Preprocess the Data

# %% [markdown]
# # 2 - Embed the documents

# %% [markdown]
# # 3 - Index embeddings in a vector database

# %% [markdown]
# # 4 - Ask a question

# %% [markdown]
# # 5 - Embed the input query

# %% [markdown]
# # 6/7 - Find relevant documents to the query

# %% [markdown]
# # 8 - Format a prompt

# %% [markdown]
# # 9 - Generate the answer

# %% [markdown]
# ![image.png](attachment:09af23ca-95d1-44ec-be2f-27f1e2138734.png)

# %% [markdown]
# https://thetechbuffet.substack.com/p/design-a-document-qa-system
